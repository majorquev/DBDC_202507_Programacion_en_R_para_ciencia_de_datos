# %% [markdown]
# <a href="https://colab.research.google.com/github/majorquev/DBDC_202507_Programacion_en_R_para_ciencia_de_datos/blob/main/Clases/Clase4/02_Visualizaciones_ggplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Parte 3: Introducción a GGplot2
#
# **Autor:** Miguel Jorquera Viguera<br>
# **E-mail:** majorquev@gmail.com<br>
# **Ayudante:** Rodrigo Morales<br>
# **E-mail ayudante:** rumorale1@gmail.com
#
# Ggplot es una librería basada en la gramática de gráficos, creadapor Wilkinson (2015). Básicamente la gramática de gráficos nos dice que un gráfico estadístico corresponde a un mapeo entre la data hacia atributos estéticos (como el color, forma o tamaño) de objetos geométricos (como puntos, líneas o barras).
#
# ## Referencias útiles
#
#  * https://ggplot2.tidyverse.org/reference/index.html
#  * https://r4ds.had.co.nz/data-visualisation.html
#  * https://www.rdocumentation.org/packages/ggplot2/versions/3.3.0
#
#
# ## Cheatsheets
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %%
# Cargamos la librería
library(ggplot2) # install.packages("ggplot2")
# Otras librerías que pueden ser de interés: leaflet, iplots, highcharter * ,ggmap, visNetwork**

# %% [markdown]
# Para entender el funcionamiento de esta grámatica comencemos con un ejemplo analizando la data mpg:

# %%
# "+" es mas o menos lo mismo en ggplot que %>% de dplyr
data(mpg)
mpg
# Out:
#     manufacturer model              displ year cyl trans      drv cty hwy fl
# 1   audi         a4                 1.8   1999 4   auto(l5)   f   18  29  p
# 2   audi         a4                 1.8   1999 4   manual(m5) f   21  29  p
# 3   audi         a4                 2.0   2008 4   manual(m6) f   20  31  p
# 4   audi         a4                 2.0   2008 4   auto(av)   f   21  30  p
# 5   audi         a4                 2.8   1999 6   auto(l5)   f   16  26  p
# 6   audi         a4                 2.8   1999 6   manual(m5) f   18  26  p
# 7   audi         a4                 3.1   2008 6   auto(av)   f   18  27  p
# 8   audi         a4 quattro         1.8   1999 4   manual(m5) 4   18  26  p
# 9   audi         a4 quattro         1.8   1999 4   auto(l5)   4   16  25  p
# 10  audi         a4 quattro         2.0   2008 4   manual(m6) 4   20  28  p
# 11  audi         a4 quattro         2.0   2008 4   auto(s6)   4   19  27  p
# 12  audi         a4 quattro         2.8   1999 6   auto(l5)   4   15  25  p
# 13  audi         a4 quattro         2.8   1999 6   manual(m5) 4   17  25  p
# 14  audi         a4 quattro         3.1   2008 6   auto(s6)   4   17  25  p
# 15  audi         a4 quattro         3.1   2008 6   manual(m6) 4   15  25  p
# 16  audi         a6 quattro         2.8   1999 6   auto(l5)   4   15  24  p
# 17  audi         a6 quattro         3.1   2008 6   auto(s6)   4   17  25  p
# 18  audi         a6 quattro         4.2   2008 8   auto(s6)   4   16  23  p
# 19  chevrolet    c1500 suburban 2wd 5.3   2008 8   auto(l4)   r   14  20  r
# 20  chevrolet    c1500 suburban 2wd 5.3   2008 8   auto(l4)   r   11  15  e
# 21  chevrolet    c1500 suburban 2wd 5.3   2008 8   auto(l4)   r   14  20  r
# 22  chevrolet    c1500 suburban 2wd 5.7   1999 8   auto(l4)   r   13  17  r
# 23  chevrolet    c1500 suburban 2wd 6.0   2008 8   auto(l4)   r   12  17  r
# 24  chevrolet    corvette           5.7   1999 8   manual(m6) r   16  26  p
# 25  chevrolet    corvette           5.7   1999 8   auto(l4)   r   15  23  p
# 26  chevrolet    corvette           6.2   2008 8   manual(m6) r   16  26  p
# 27  chevrolet    corvette           6.2   2008 8   auto(s6)   r   15  25  p
# 28  chevrolet    corvette           7.0   2008 8   manual(m6) r   15  24  p
# 29  chevrolet    k1500 tahoe 4wd    5.3   2008 8   auto(l4)   4   14  19  r
# 30  chevrolet    k1500 tahoe 4wd    5.3   2008 8   auto(l4)   4   11  14  e
# ⋮   ⋮            ⋮                  ⋮     ⋮    ⋮   ⋮          ⋮   ⋮   ⋮   ⋮
# 205 toyota       toyota tacoma 4wd  3.4   1999 6   auto(l4)   4   15  19  r
# 206 toyota       toyota tacoma 4wd  4.0   2008 6   manual(m6) 4   15  18  r
# 207 toyota       toyota tacoma 4wd  4.0   2008 6   auto(l5)   4   16  20  r
# 208 volkswagen   gti                2.0   1999 4   manual(m5) f   21  29  r
# 209 volkswagen   gti                2.0   1999 4   auto(l4)   f   19  26  r
# 210 volkswagen   gti                2.0   2008 4   manual(m6) f   21  29  p
# 211 volkswagen   gti                2.0   2008 4   auto(s6)   f   22  29  p
# 212 volkswagen   gti                2.8   1999 6   manual(m5) f   17  24  r
# 213 volkswagen   jetta              1.9   1999 4   manual(m5) f   33  44  d
# 214 volkswagen   jetta              2.0   1999 4   manual(m5) f   21  29  r
# 215 volkswagen   jetta              2.0   1999 4   auto(l4)   f   19  26  r
# 216 volkswagen   jetta              2.0   2008 4   auto(s6)   f   22  29  p
# 217 volkswagen   jetta              2.0   2008 4   manual(m6) f   21  29  p
# 218 volkswagen   jetta              2.5   2008 5   auto(s6)   f   21  29  r
# 219 volkswagen   jetta              2.5   2008 5   manual(m5) f   21  29  r
# 220 volkswagen   jetta              2.8   1999 6   auto(l4)   f   16  23  r
# 221 volkswagen   jetta              2.8   1999 6   manual(m5) f   17  24  r
# 222 volkswagen   new beetle         1.9   1999 4   manual(m5) f   35  44  d
# 223 volkswagen   new beetle         1.9   1999 4   auto(l4)   f   29  41  d
# 224 volkswagen   new beetle         2.0   1999 4   manual(m5) f   21  29  r
# 225 volkswagen   new beetle         2.0   1999 4   auto(l4)   f   19  26  r
# 226 volkswagen   new beetle         2.5   2008 5   manual(m5) f   20  28  r
# 227 volkswagen   new beetle         2.5   2008 5   auto(s6)   f   20  29  r
# 228 volkswagen   passat             1.8   1999 4   manual(m5) f   21  29  p
# 229 volkswagen   passat             1.8   1999 4   auto(l5)   f   18  29  p
# 230 volkswagen   passat             2.0   2008 4   auto(s6)   f   19  28  p
# 231 volkswagen   passat             2.0   2008 4   manual(m6) f   21  29  p
# 232 volkswagen   passat             2.8   1999 6   auto(l5)   f   16  26  p
# 233 volkswagen   passat             2.8   1999 6   manual(m5) f   18  26  p
# 234 volkswagen   passat             3.6   2008 6   auto(s6)   f   17  26  p
#     class
# 1   compact
# 2   compact
# 3   compact
# 4   compact
# 5   compact
# 6   compact
# 7   compact
# 8   compact
# 9   compact
# 10  compact
# 11  compact
# 12  compact
# 13  compact
# 14  compact
# 15  compact
# 16  midsize
# 17  midsize
# 18  midsize
# 19  suv
# 20  suv
# 21  suv
# 22  suv
# 23  suv
# 24  2seater
# 25  2seater
# 26  2seater
# 27  2seater
# 28  2seater
# 29  suv
# 30  suv
# ⋮   ⋮
# 205 pickup
# 206 pickup
# 207 pickup
# 208 compact
# 209 compact
# 210 compact
# 211 compact
# 212 compact
# 213 compact
# 214 compact
# 215 compact
# 216 compact
# 217 compact
# 218 compact
# 219 compact
# 220 compact
# 221 compact
# 222 subcompact
# 223 subcompact
# 224 subcompact
# 225 subcompact
# 226 subcompact
# 227 subcompact
# 228 midsize
# 229 midsize
# 230 midsize
# 231 midsize
# 232 midsize
# 233 midsize
# 234 midsize

# %%
plot(mpg$displ, mpg$hwy, col = "blue")
# Out:
# plot without title

# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
mpg %>%
    ggplot() + # Indicamos el origen de los datos que buscamos visualizar
    aes(x = displ, y = hwy) + # capa "estética" : aesthetical mapping (indicamos qué variables queremos visualizar)
    geom_point() # capa geométrica, se indica "cómo" queremos visualizar las variables indicadas en el aesthetical mapping
# Out:
# plot without title

# %%
# tambien podemos generar el gráfico de la siguiente manera (aes( coo parametro mapping))
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) +
    geom_point()
# Out:
# plot without title

# %% [markdown]
# # I. Color, tamaño, forma y otros atributos estéticos
#
# ## I.1. Color
# El color está dado por la variable categórica class (notar que es lo mismo si incluimos el parámetro color, colour o col. ggplot automáticamente entiende lo que queremos :) )

# %%
## Color por "class" dentro de aes
mpg %>%
    ggplot() +
    aes(x = displ, y = hwy, color = class) +
    geom_point()
# Out:
# plot without title

# %%
# y si queremos color azul?
mpg %>%
    ggplot() +
    aes(x = displ, y = hwy, colour = "black") +
    geom_point()
# Out:
# plot without title

# %%
mpg %>%
    ggplot() +
    aes(x = displ, y = hwy) +
    geom_point(color = "#82e8cb")
# Out:
# plot without title

# %%
# Que pasa si queremos colorear en negro solo los de class "2seater" y los otros en rojo.
mpg %>%
  # mutate(es_2seater = class == "2seater") #Op1 como booleano
  mutate(es_2seater = ifelse(class == "2seater", "SI", "NO")) %>%
  ggplot() +
  aes(x = displ, y = hwy, color = es_2seater) +
  geom_point() +
  scale_color_manual(values = c("red", "black"))
# Out:
# plot without title

# %%
head(mpg)
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
# que sucede si el color no es una variable discreta (categórica)
mpg %>%
  ggplot() +
  aes(x = displ, y = hwy, color = cty) +
  geom_point()
# Out:
# plot without title

# %%
# Modificar la escala de colores y dar la impresión de "intensidad"
mpg %>%
  ggplot() +
  aes(x = displ, y = hwy, color = cty) +
  geom_point() +
  scale_color_continuous(low = "blue", high = "red")
# Out:
# plot without title

# %% [markdown]
# ## I.2. Forma

# %%
## Forma (shape) según "drv"
mpg %>%
  ggplot() +
  aes(x = displ, y = hwy, shape = drv) +
  geom_point()
# Out:
# plot without title

# %%
# El parámetro alpha permite regular la intensidad el color en función de la densidad de los puntos.

# %% [markdown]
# ## I.3. Forma y color

# %%
## Forma y color (color = class, shape = drv)
mpg %>%
  ggplot() +
  aes(x = displ, y = hwy, shape = drv, color = class) +
  geom_point()
# Out:
# plot without title

# %% [markdown]
# ## I.4. Tamaño

# %%
## Tamaño (size) según "cyl"
mpg %>%
  ggplot() +
  aes(x = displ, y = hwy, size = cyl) +
  geom_point()
# Out:
# plot without title

# %%
# size = drv? nota: no tiene sentido dar el tamaño segú nuna variable categórica (R internamente la ordena alfabéticamente y luego asigna el valor del tamañao)
mpg %>%
  ggplot() +
  aes(x = displ, y = hwy, size = drv) +
  geom_point()
# Out:
# Warning message:
# “Using size for a discrete variable is not advised.”
# plot without title

# %% [markdown]
# # II. Facetas
#
# En inglés Facetting, es una manera de dividir la data disponible según variables categóricas y mostrar el mismo gráfico por cada categoría en una misma imagen.

# %%
# Apertura por drv # Small multiples de power BI.
mpg %>%
  ggplot() +
  aes(x = displ, y = hwy) +
  geom_point() +
  facet_wrap(~ drv)
# Out:
# plot without title

# %% [markdown]
# Grafique otras relaciones entre la eficiencia (hwy o cty), tamaño del motor (displ) por cada  número de cilindros (cyl). ¿Qué se observa?

# %%
# Por ejemplo, x=displ,y=hwy , aperturado por número de cilindros

# %% [markdown]
# # III. Capas geométricas: prefijo geom_
#
# Hasta aquí hemos utilizado sólo una de las diversas maneras de mostrar (geométricamente hablando) la relación entre las variables hasta aquí descritas.
# En ggplot existe una gran variedad de funciones "geom_", sólo veremos algunas de ellas, aunque en la documentación oficial se describen todas las opciones disponibles https://ggplot2.tidyverse.org/index.html
#
# ## III.1 geom_point()
#
# La fución geom_point() se encarga de visualizar las variables definidas en aes() como un gráfico de dispersión.
#
# ## III.2 geom_smooth()
# Con esta función podemos añadir una curva de tendencia a nuestros datos

# %%
#geom_smooth()
mpg %>%
  ggplot() +
  aes(x = displ, y = hwy) +
  geom_point() +
  geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %%
#geom_smooth()
mpg %>%
  ggplot() +
  aes(x = displ, y = hwy) +
  geom_point() +
  geom_smooth(method = "lm")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# ¿Cómo podemos graficar las curvas de tendencia para cada tipo de tracción (drv)?

# %%
# por color
#geom_smooth()
mpg %>%
  ggplot() +
  aes(x = displ, y = hwy, color = drv) +
  geom_point() +
  geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %%
# y usando facet_wrap
mpg %>%
  ggplot() +
  aes(x = displ, y = hwy) +
  geom_point() +
  geom_smooth() +
  facet_wrap(~ drv)
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %% [markdown]
# ## III.3 geom_boxplot() y geom_jitter()
#  Podemos variar la forma del gráfico modificando la capa geométrica con las funciones geom_
#  Por ejemplo, hace un rato visualizamos la relación entre hwy y drv. Para este tipo de relaciones es más informativo un gráfico de cajas.

# %%
mpg %>%
  ggplot() +
  aes(x = drv, y = hwy) +
  geom_point()
# Out:
# plot without title

# %%
mpg %>%
  ggplot() +
  aes(x = drv, y = hwy) +
  geom_point(col = "red")+
  geom_jitter(col = "black")
# Out:
# plot without title

# %%
# Boxplots
mpg %>%
  ggplot() +
  aes(x = drv, y = hwy) +
  geom_boxplot()
# Out:
# plot without title

# %%
## histograma . Parámetro bins =30 en geom_histogram()
mpg %>%
  ggplot() +
  aes(x = 0, y = hwy) +
  geom_boxplot() +
  geom_jitter(color = "red")
# Out:
# plot without title

# %% [markdown]
# ## III.4 geom_histogram() y  geom_freqpoly()
#
# Con estas funciones es posible graficar histogramas y la frecuencia absoluta a través de una curva poligonal

# %%
## histograma . Parámetro bins =30 por defecto en geom_histogram()
mpg %>%
  ggplot() +
  aes(x = hwy) +
  geom_histogram(bins = 20)
# Out:
# plot without title

# %%
?hist

# %%
# Con base
hist(mpg$hwy,breaks = 19)
# Out:
# Plot with title “Histogram of mpg$hwy”

# %%
# podemos aperturar por drv (en color  y fill)
mpg %>%
  ggplot() +
  aes(x = hwy, color = drv, fill = drv) +
  geom_histogram(bins = 20)

#usando facet_wrap
mpg %>%
  ggplot() +
  aes(x = hwy) +
  geom_histogram(bins = 20) +
  facet_wrap(~drv)
# Out:
# plot without title
# plot without title

# %%
## polígono de frecuencias # geom_freqpoly
mpg %>%
  ggplot() +
  aes(x = hwy, col = drv) +
  geom_freqpoly(bins = 20)
# Out:
# plot without title

# %% [markdown]
# ## III.4 geom_line()
#
# Podemos generar gráficos de linea, por ejemplo de series temporales.

# %%
library(dplyr)
library(httr)
library(jsonlite)
library(ggplot2)

url_base <-"https://mindicador.cl"

consulta <- GET(url_base,path = "/api/dolar/2025")
consulta
# Out:
# Response [https://mindicador.cl/api/dolar/2025]
#   Date: 2025-08-13 23:47
#   Status: 200
#   Content-Type: application/json; charset=utf-8
#   Size: 8.24 kB

# %%
text <- content(consulta, as = "text")
text
# Out:
# [1] "{\"version\":\"1.7.0\",\"autor\":\"mindicador.cl\",\"codigo\":\"dolar\",\"nombre\":\"Dólar observado\",\"unidad_medida\":\"Pesos\",\"serie\":[{\"fecha\":\"2025-08-14T04:00:00.000Z\",\"valor\":952.37},{\"fecha\":\"2025-08-13T04:00:00.000Z\",\"valor\":962.28},{\"fecha\":\"2025-08-12T04:00:00.000Z\",\"valor\":969.77},{\"fecha\":\"2025-08-11T04:00:00.000Z\",\"valor\":965.64},{\"fecha\":\"2025-08-08T04:00:00.000Z\",\"valor\":971.88},{\"fecha\":\"2025-08-07T04:00:00.000Z\",\"valor\":976.42},{\"fecha\":\"2025-08-06T04:00:00.000Z\",\"valor\":966.02},{\"fecha\":\"2025-08-05T04:00:00.000Z\",\"valor\":964.28},{\"fecha\":\"2025-08-04T04:00:00.000Z\",\"valor\":967.48},{\"fecha\":\"2025-08-01T04:00:00.000Z\",\"valor\":976.8},{\"fecha\":\"2025-07-31T04:00:00.000Z\",\"valor\":978.07},{\"fecha\":\"2025-07-30T04:00:00.000Z\",\"valor\":970.09},{\"fecha\":\"2025-07-29T04:00:00.000Z\",\"valor\":969.75},{\"fecha\":\"2025-07-28T04:00:00.000Z\",\"valor\":957.82},{\"fecha\":\"2025-07-25T04:00:00.000Z\",\"valor\":951.27},{\"fecha\":\"2025-07-24T04:00:00.000Z\",\"valor\":948.93},{\"fecha\":\"2025-07-23T04:00:00.000Z\",\"valor\":953.4},{\"fecha\":\"2025-07-22T04:00:00.000Z\",\"valor\":956.65},{\"fecha\":\"2025-07-21T04:00:00.000Z\",\"valor\":961.55},{\"fecha\":\"2025-07-18T04:00:00.000Z\",\"valor\":966.78},{\"fecha\":\"2025-07-17T04:00:00.000Z\",\"valor\":965.65},{\"fecha\":\"2025-07-15T04:00:00.000Z\",\"valor\":967.22},{\"fecha\":\"2025-07-14T04:00:00.000Z\",\"valor\":955.73},{\"fecha\":\"2025-07-11T04:00:00.000Z\",\"valor\":950.43},{\"fecha\":\"2025-07-10T04:00:00.000Z\",\"valor\":948.33},{\"fecha\":\"2025-07-09T04:00:00.000Z\",\"valor\":945.39},{\"fecha\":\"2025-07-08T04:00:00.000Z\",\"valor\":940.28},{\"fecha\":\"2025-07-07T04:00:00.000Z\",\"valor\":932.34},{\"fecha\":\"2025-07-04T04:00:00.000Z\",\"valor\":927.87},{\"fecha\":\"2025-07-03T04:00:00.000Z\",\"valor\":926.51},{\"fecha\":\"2025-07-02T04:00:00.000Z\",\"valor\":926.62},{\"fecha\":\"2025-07-01T04:00:00.000Z\",\"valor\":933.42},{\"fecha\":\"2025-06-30T04:00:00.000Z\",\"valor\":935.74},{\"fecha\":\"2025-06-27T04:00:00.000Z\",\"valor\":930.67},{\"fecha\":\"2025-06-26T04:00:00.000Z\",\"valor\":936.29},{\"fecha\":\"2025-06-25T04:00:00.000Z\",\"valor\":937.89},{\"fecha\":\"2025-06-24T04:00:00.000Z\",\"valor\":950.16},{\"fecha\":\"2025-06-23T04:00:00.000Z\",\"valor\":947.03},{\"fecha\":\"2025-06-19T04:00:00.000Z\",\"valor\":943.36},{\"fecha\":\"2025-06-18T04:00:00.000Z\",\"valor\":939.29},{\"fecha\":\"2025-06-17T04:00:00.000Z\",\"valor\":935.21},{\"fecha\":\"2025-06-16T04:00:00.000Z\",\"valor\":937.78},{\"fecha\":\"2025-06-13T04:00:00.000Z\",\"valor\":930.25},{\"fecha\":\"2025-06-12T04:00:00.000Z\",\"valor\":936.36},{\"fecha\":\"2025-06-11T04:00:00.000Z\",\"valor\":938.88},{\"fecha\":\"2025-06-10T04:00:00.000Z\",\"valor\":937.09},{\"fecha\":\"2025-06-09T04:00:00.000Z\",\"valor\":933.91},{\"fecha\":\"2025-06-06T04:00:00.000Z\",\"valor\":930.79},{\"fecha\":\"2025-06-05T04:00:00.000Z\",\"valor\":936.89},{\"fecha\":\"2025-06-04T04:00:00.000Z\",\"valor\":941.53},{\"fecha\":\"2025-06-03T04:00:00.000Z\",\"valor\":939.65},{\"fecha\":\"2025-06-02T04:00:00.000Z\",\"valor\":941.97},{\"fecha\":\"2025-05-30T04:00:00.000Z\",\"valor\":937.37},{\"fecha\":\"2025-05-29T04:00:00.000Z\",\"valor\":940.21},{\"fecha\":\"2025-05-28T04:00:00.000Z\",\"valor\":937.93},{\"fecha\":\"2025-05-27T04:00:00.000Z\",\"valor\":938.28},{\"fecha\":\"2025-05-26T04:00:00.000Z\",\"valor\":940.81},{\"fecha\":\"2025-05-23T04:00:00.000Z\",\"valor\":944.84},{\"fecha\":\"2025-05-22T04:00:00.000Z\",\"valor\":942.21},{\"fecha\":\"2025-05-20T04:00:00.000Z\",\"valor\":936.69},{\"fecha\":\"2025-05-19T04:00:00.000Z\",\"valor\":944.46},{\"fecha\":\"2025-05-16T04:00:00.000Z\",\"valor\":940.25},{\"fecha\":\"2025-05-15T04:00:00.000Z\",\"valor\":939.43},{\"fecha\":\"2025-05-14T04:00:00.000Z\",\"valor\":940.18},{\"fecha\":\"2025-05-13T04:00:00.000Z\",\"valor\":941.2},{\"fecha\":\"2025-05-12T04:00:00.000Z\",\"valor\":933.26},{\"fecha\":\"2025-05-09T04:0 ...

# %%
content <- fromJSON(text)

# %%
class(content)
# Out:
# [1] "list"

# %%
str(content)
# Out:
# List of 6
#  $ version      : chr "1.7.0"
#  $ autor        : chr "mindicador.cl"
#  $ codigo       : chr "dolar"
#  $ nombre       : chr "Dólar observado"
#  $ unidad_medida: chr "Pesos"
#  $ serie        :'data.frame':	156 obs. of  2 variables:
#   ..$ fecha: chr [1:156] "2025-08-14T04:00:00.000Z" "2025-08-13T04:00:00.000Z" "2025-08-12T04:00:00.000Z" "2025-08-11T04:00:00.000Z" ...
#   ..$ valor: num [1:156] 952 962 970 966 972 ...

# %%
dolar_2025 <- content$serie

# %%
head(dolar_2025)
# Out:
#   fecha                    valor
# 1 2025-08-14T04:00:00.000Z 952.37
# 2 2025-08-13T04:00:00.000Z 962.28
# 3 2025-08-12T04:00:00.000Z 969.77
# 4 2025-08-11T04:00:00.000Z 965.64
# 5 2025-08-08T04:00:00.000Z 971.88
# 6 2025-08-07T04:00:00.000Z 976.42

# %%
dolar_2025 %>%
  mutate(fecha = as.Date(fecha)) %>%
  ggplot() +
  aes(x = fecha , y = valor) +
  geom_line()
# Out:
# plot without title

# %% [markdown]
# # IV. Otros parámetros visuales
# ## IV.1 Etiquetas
# Con la capa llamada `labs()`, podemos modificar los nombres de los ejes, títulos, subtítulos y leyenda.

# %%
## Ejemplo, consideramos incluir etiquetas y cortes en el eje de tiempo
g1 <- dolar_2025 %>%
  mutate(fecha = as.Date(fecha)) %>%
  ggplot() +
  aes(x = fecha , y = valor) +
  geom_line(col = "red") +
  labs(title = "Valor del dólar observado",
       subtitle = "Serie para el año 2025",
       y = "Valor del dólar observado",
       x = "Fecha de registro",
       caption = "Fuente: https://mindicador.cl/") +
  geom_smooth()

# %%
g1
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %% [markdown]
# ## IV.2 Ejes y escala
# Existen diversas funciones que nos peritirán modificar parámetros visuales de los ejes, en función del tipo de dato que estos representen. Algunos de los más usuales son los siguientes
#  * `scale_x_date()`, `scale_y_date()`
#  * `scale_x_continuous()`, `scale_y_continuous()`
#  * `scale_x_discrete()`, `scale_y_discrete()`
#  * `scale_x_log10()`, `scale_y_log10()`
#
# En la documentación pueden buscar las demmás opcione mediante el prefijo _scale_

# %%
g1 +
  scale_x_date(date_breaks = "1 month", date_labels = "%b %y")
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %% [markdown]
# # Opcional
# Podemos recurrir a un cliclo `for()`, si quisiéramos rescatr varios años del valor del dolar.

# %%
url_base <-"https://mindicador.cl"

dolar_hist <- data.frame()

for(anio in 2020:2025){
  consulta <- GET(url_base, path = paste0("/api/dolar/",anio) )
  text <- content(consulta, as = "text")
  content <- fromJSON(text)
  dolar_hist <- rbind(dolar_hist,content$serie)
  print(paste("Consulta del año: ", anio) )
  }
# Out:
# [1] "Consulta del año:  2020"
# [1] "Consulta del año:  2021"
# [1] "Consulta del año:  2022"
# [1] "Consulta del año:  2023"
# [1] "Consulta del año:  2024"
# [1] "Consulta del año:  2025"

# %%
nrow(dolar_2025)
nrow(dolar_hist)
# Out:
# [1] 156
# [1] 1403

# %%
head(dolar_hist)
tail(dolar_hist)
# Out:
#   fecha                    valor
# 1 2020-12-30T03:00:00.000Z 711.24
# 2 2020-12-29T03:00:00.000Z 710.64
# 3 2020-12-28T03:00:00.000Z 710.26
# 4 2020-12-24T03:00:00.000Z 716.25
# 5 2020-12-23T03:00:00.000Z 728.96
# 6 2020-12-22T03:00:00.000Z 730.70
#      fecha                    valor
# 1398 2025-01-09T03:00:00.000Z 1007.51
# 1399 2025-01-08T03:00:00.000Z 1005.85
# 1400 2025-01-07T03:00:00.000Z 1010.98
# 1401 2025-01-06T03:00:00.000Z 1011.82
# 1402 2025-01-03T03:00:00.000Z  999.84
# 1403 2025-01-02T03:00:00.000Z  996.46

# %% [markdown]
# # Guardar un gráfico en el directorio local
# Podemos guardar nuestros gráficos en un  directorio local con funciones propias de ggplot2.
# ```
# ggsave(
#   filename,
#   plot = last_plot(),
#   device = NULL,
#   path = NULL,
#   scale = 1,
#   width = NA,
#   height = NA,
#   units = c("in", "cm", "mm", "px"),
#   dpi = 300,
#   limitsize = TRUE,
#   bg = NULL,
#   create.dir = FALSE,
#   ...
# )
# ```

# %%
ggsave(filename = "dolar_2025.png",plot = g1)
# Out:
# Saving 6.67 x 6.67 in image
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
